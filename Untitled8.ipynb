# %%
i = 10
while(i<=200):
  print(i,end="")
  i = i+10
# Out:
# 102030405060708090100110120130140150160170180190200

# %%
def painter():
  print("painting")

  painter()

# %%
def greet(name):
  print("hello" , name)
  print("how are you")

greet("kasthuri")
print("******")
greet("appa")
# Out:
# hello kasthuri
# how are you
# ******
# hello appa
# how are you

# %%
def add():
  a = int(input())
  b = int(input())
  print(a+b);
  add()

# %%
def add():
  print("addiction")
  a = int(input("enter a number"))
  b = int(input("enter a number"))
  print(a+b)

def substraction():
  print("substraction")
  a = int(input("enter a number"))
  b = int(input("enter a number"))
  print(a-b)

add()
substraction()
# Out:
# addiction
# enter a number10
# enter a number5
# 15
# substraction
# enter a number20
# enter a number5
# 15

# %%
def greet(name):
  print("hello" , "kasthuri")
greet("name")
# Out:
# hello kasthuri
