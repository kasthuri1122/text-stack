# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


x_train = np.array([-2.0, -1.0, 0.0, 1.0, 2.0], dtype=float)
y_train = np.array([-13.0, -8.0, -3.0, 2.0, 7.0], dtype=float)


model = Sequential([
    Dense(units=1, input_shape=[1])
])


model.compile(optimizer='sgd', loss='mean_squared_error')


print("Training the model...")
model.fit(x_train, y_train, epochs=500, verbose=0)
print("Model training complete.")


x_test = -2.0
y_pred = model.predict(np.array([x_test]))

print(f"Prediction for x = {x_test}: {y_pred[0][0]:.2f}")
# Out:
# Training the model...
# Model training complete.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Prediction for x = -2.0: -13.00

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
x_train = np.array([-2.0, -1.0, 0.0, 1.0, 2.0], dtype=float)
y_train = np.array([-4.0, -1.0, 2.0, 5.0, 8.0], dtype=float)
model = Sequential([
    Dense(units=3, activation='relu', input_shape=[1]),
    Dense(units=1) ])
model.compile(optimizer='adam', loss='mean_squared_error')
print("Training the model...")
model.fit(x_train, y_train, epochs=500, verbose=0)
print("Model training complete.")
x_test = 3.0
y_pred = model.predict(np.array([x_test]))
print(f"Prediction for x = {x_test}: {y_pred[0][0]:.2f}")
print("\nModel Summary:")
model.summary()
print("\nWeights and Biases:")
for layer in model.layers:
    weights, bias = layer.get_weights()
    print(f"Weights:\n{weights}\nBias:\n{bias}")
# Out:
# Training the model...
# Model training complete.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Prediction for x = 3.0: 8.55
#
# Model Summary:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 3)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32 (132.00 B)
#  Trainable params: 10 (40.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 22 (92.00 B)
# Weights and Biases:
# Weights:
# [[-1.1829354  1.2517906  1.301766 ]]
# Bias:
# [0.2877842  0.46005887 0.48506758]
# Weights:
# [[-1.1776462 ]
# ...
