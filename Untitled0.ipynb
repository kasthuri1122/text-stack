# %%
4
# Out:
# 4

# %%
a=5
print (a)
# Out:
# 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a=2.33
print(a)
# Out:
# 2.33

# %%
a=("1,2,3")
print(type(a))
# Out:
# <class 'str'>

# %%
a=("1,2,3")
print(typ(a))
# Out:
# 1,2,3

# %%
n=(1,2,3,4,5)
print(type(n))
# Out:
# <class 'tuple'>

# %%
a=[1,2,3,4]
print(a)
print(type(a))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
o={1,2,3}
print(type(o))
# Out:
# <class 'set'>

# %%
q=[1,2,3,4,5]
print(q)
print(type(q))
print(q[-4:-2])
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# [2, 3]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-3694456b1dc8> in <cell line: 0>()
#       1 p={1,2,3,4,5,6}
#       2 q={7,8,9,10,11}
# ----> 3 a=b.union(q)
#       4 print(q)
#
# NameError: name 'b' is not defined
