# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"/content/kasthuri dataset 1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          27901 non-null  object
#  1   Age             27901 non-null  int64
#  2   City            27901 non-null  object
#  3   Profession      27901 non-null  object
#  4   Sleep Duration  27901 non-null  object
#  5   Dietary Habits  27901 non-null  object
#  6   Degree          27901 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.5+ MB

# %%
df.head()
# Out:
#    Gender  Age           City Profession       Sleep Duration Dietary Habits  \
# 0    Male   33  Visakhapatnam    Student          '5-6 hours'        Healthy
# 1  Female   24      Bangalore    Student          '5-6 hours'       Moderate
# 2    Male   31       Srinagar    Student  'Less than 5 hours'        Healthy
# 3  Female   28       Varanasi    Student          '7-8 hours'       Moderate
# 4  Female   25         Jaipur    Student          '5-6 hours'       Moderate
#
#     Degree
# 0  B.Pharm
# 1      BSc
# 2       BA
# 3      BCA
# 4   M.Tech

# %%
df.tail()
# Out:
#        Gender  Age       City Profession       Sleep Duration Dietary Habits  \
# 27896  Female   27      Surat    Student          '5-6 hours'      Unhealthy
# 27897    Male   27   Ludhiana    Student  'Less than 5 hours'        Healthy
# 27898    Male   31  Faridabad    Student          '5-6 hours'      Unhealthy
# 27899  Female   18   Ludhiana    Student  'Less than 5 hours'        Healthy
# 27900    Male   27      Patna    Student  'Less than 5 hours'        Healthy
#
#            Degree
# 27896  'Class 12'
# 27897         MSc
# 27898          MD
# 27899  'Class 12'
# 27900         BCA

# %%
df.iloc[2]
# Out:
# Gender                           Male
# Age                                31
# City                         Srinagar
# Profession                    Student
# Sleep Duration    'Less than 5 hours'
# Dietary Habits                Healthy
# Degree                             BA
# Name: 2, dtype: object

# %%
df[:3]
# Out:
#    Gender  Age           City Profession       Sleep Duration Dietary Habits  \
# 0    Male   33  Visakhapatnam    Student          '5-6 hours'        Healthy
# 1  Female   24      Bangalore    Student          '5-6 hours'       Moderate
# 2    Male   31       Srinagar    Student  'Less than 5 hours'        Healthy
#
#     Degree
# 0  B.Pharm
# 1      BSc
# 2       BA

# %%
df[3:6]
# Out:
#    Gender  Age      City Profession       Sleep Duration Dietary Habits  \
# 3  Female   28  Varanasi    Student          '7-8 hours'       Moderate
# 4  Female   25    Jaipur    Student          '5-6 hours'       Moderate
# 5    Male   29      Pune    Student  'Less than 5 hours'        Healthy
#
#    Degree
# 3     BCA
# 4  M.Tech
# 5     PhD
